# %% [markdown]
# # HEINITZ-PRIME: KAGGLE DRY RUN
# ## Projekt Ariadna v2.0 - Test 3 Modeli
#
# Ten notatnik wykonuje *Dry Run* systemu hybrydowego z opcjonalnymi podłączeniami po API. Pamiętaj aby ustawić w zakładce **Add-ons -> Secrets**:
# - `QDRANT_API_KEY` oraz `QDRANT_URL` (dla wektoryzacji Qdrant, opcjonalnie)
# - `Qwen` (dla API HuggingFace - Qwen)
# - `Gemini API Key` (dla Gemini Mutatora i wariantu Blank)

# %%
# Instalacja niezbędnego minimum
# !pip install -q qdrant-client requests pydantic python-dotenv tiktoken pyyaml google-genai

# %%
import sys
sys.path.append('src')

import orchestrator

# START: GŁÓWNA PĘTLA HYBRYDOWEGO KROSNA
orchestrator.main()
