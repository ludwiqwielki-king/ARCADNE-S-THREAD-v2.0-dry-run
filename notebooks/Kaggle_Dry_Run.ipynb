# %% [markdown]
# # HEINITZ-PRIME: KAGGLE DRY RUN
# ## Projekt Ariadna v2.0 - Test 3 Modeli
#
# Ten notatnik wykonuje *Dry Run* systemu hybrydowego z opcjonalnymi podłączeniami po API. Pamiętaj aby ustawić w zakładce **Add-ons -> Secrets**:
# - `OPENAI_API_KEY` (dla wektoryzacji Qdrant, opcjonalnie)
# - `HF_TOKEN` (dla API HuggingFace - Qwen)
# - `GOOGLE_API_KEY` (dla Gemini Mutatora i wariantu Blank)
# - `QDRANT_URL` oraz `QDRANT_API_KEY`

# %%
# Instalacja niezbędnego minimum
# !pip install -q qdrant-client requests pydantic python-dotenv tiktoken

# %%
import sys
sys.path.append('src')

import orchestrator

# START: GŁÓWNA PĘTLA HYBRYDOWEGO KROSNA
orchestrator.main()
